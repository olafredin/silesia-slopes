# %% [markdown]
# # Notebook NN — *Title of this notebook*
#
# **Short course:** *Geomorphological Hazards of Slopes* &nbsp;•&nbsp; University of Silesia in Katowice &nbsp;•&nbsp; 2 ECTS
#
# *Lecturer: Ola Fredin*
#
# ---
#
# This is the **template** for every notebook in the course portfolio. Copy this file, rename it (`NN_topic.ipynb`), and fill in the sections below. The structure is deliberately repetitive so students always know where to find theory, the worked example, the interactive bit, and the exam questions.

# %% [markdown]
# ## About this notebook
#
# **Learning objectives.** By the end of this notebook the student will be able to:
#
# 1. *State the first learning objective here.*
# 2. *State the second learning objective here.*
# 3. *State the third learning objective here.*
#
# **Prerequisites.** Notebooks `0X` and `0Y`, plus the lecture on *<topic>*.
#
# > **For your PowerPoint deck.** The figures saved to `figures/<name>.svg` are the ones intended for the slides. SVG paste perfectly into PowerPoint (right-click → *Paste Special* → SVG, or just drag the file in). Equations rendered in markdown cells can be screenshotted with consistent typography because every notebook uses the same `mathtext.fontset = "cm"` style.

# %%
# Setup — same first cell in every notebook.
import numpy as np
import matplotlib.pyplot as plt

from style import apply_style, COLORS, save_figure
apply_style()

# Optional: only needed if the notebook has interactive widgets.
# from ipywidgets import interact, FloatSlider

# %% [markdown]
# ## 1. Theory
#
# Write the conceptual narrative here in plain prose, with key equations set off as their own line. Number every equation you might want to refer to later (or screenshot for slides):
#
# $$
# \boxed{\;y = f(x)\;} \qquad (1)
# $$
#
# A second equation:
#
# $$
# \sigma' \;=\; \sigma - u \qquad (2)
# $$
#
# Keep equations short and labelled — easier to copy into slides.

# %%
# A small, self-contained illustrative computation.
x = np.linspace(0, 10, 200)
y = np.sin(x) * np.exp(-x / 8)

fig, ax = plt.subplots()
ax.plot(x, y, color=COLORS["accent"], label=r"$y = \sin(x)\,e^{-x/8}$")
ax.set_xlabel(r"$x$")
ax.set_ylabel(r"$y$")
ax.set_title("Example figure — replace with the real one")
ax.legend()

save_figure(fig, "template_example")
plt.show()

# %% [markdown]
# ## 2. Interactive exploration
#
# Use an `ipywidgets` slider so students can change one or two parameters and see the response live. Keep it to **two sliders maximum** — more than that and students start fiddling instead of thinking.

# %%
# Interactive widget — replace with the real exploration.
# Uncomment when ipywidgets is needed.
#
# from ipywidgets import interact, FloatSlider
#
# def explore(a=1.0, b=0.1):
#     fig, ax = plt.subplots()
#     ax.plot(x, a * np.sin(x) * np.exp(-b * x), color=COLORS["accent"])
#     ax.set_xlabel(r"$x$"); ax.set_ylabel(r"$y$")
#     ax.set_title(f"a = {a:.2f},  b = {b:.3f}")
#     plt.show()
#
# interact(explore,
#          a=FloatSlider(0.5, 2.0, 0.1, value=1.0, description="amplitude"),
#          b=FloatSlider(0.0, 0.5, 0.02, value=0.1, description="decay"))

# %% [markdown]
# ## 3. Worked example
#
# A single concrete case study — ideally with regionally relevant numbers (Carpathians, Sudetes, Tatras, Norwegian fjord slopes). Show the *inputs*, the *computation*, and the *interpretation* in plain language.

# %%
# Worked example — placeholder.
inputs = dict(parameter_1=1.0, parameter_2=2.0)
result = inputs["parameter_1"] + inputs["parameter_2"]
print(f"Inputs: {inputs}")
print(f"Result: {result:.2f}")

# %% [markdown]
# ## Take-aways
#
# - *First key idea, in one sentence.*
# - *Second key idea, in one sentence.*
# - *Third key idea, linking back to the lecture.*
#
# ## Questions for the exam
#
# 1. *A short conceptual question.*
# 2. *A short calculation, with given inputs.*
# 3. *A short interpretation question on a regional example.*
#
# ## References
#
# - *Author (Year)*, full citation.
# - *Author (Year)*, full citation.
